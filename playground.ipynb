# %% [markdown]
# ## Research Question
#
# How can a ML model be created to predict the fluctuation of traffic volume within a year after the construction of a data center in Northern Virginia?
# s

# %%
import pandas as pd
import openpyxl

# %%
df_2025 = pd.read_excel('Datasets_2011_til_2025/aadt_053_loudoun_2025.xlsx', skiprows=6)

df_2025.head()
# Out:
#   Link ID    RNS Route Name Route Label           Route Alias  \
# 0  190119  R-VA   SR00007EB     VA 7 EB  Harry Flood Byrd Hwy
# 1  090049  R-VA   SR00007EB     VA 7 EB  Harry Flood Byrd Hwy
# 2  090049  R-VA   SR00007EB     VA 7 EB  Harry Flood Byrd Hwy
# 3  190120  R-VA   SR00007EB     VA 7 EB  Harry Flood Byrd Hwy
# 4  190120  R-VA   SR00007EB     VA 7 EB  Harry Flood Byrd Hwy
#
#    Physical Jurisdiction      Unnamed: 5 Maintenance Jurisdiction  \
# 0                   53.0  Loudoun County                      053
# 1                   53.0  Loudoun County                      053
# 2                   53.0  Loudoun County                      053
# 3                   53.0  Loudoun County                      053
# 4                   53.0  Loudoun County                      053
#
#        Unnamed: 7                  Start Label                      End Label  \
# 0  Loudoun County           Clarke County Line           53-760 Near Bluemont
# ...
